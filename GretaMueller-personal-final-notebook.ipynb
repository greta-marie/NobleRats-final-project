# %% [markdown]
# # personal Jupyterhub notebook for final project with Mofe and Linda
# # Date started: 11/9/2022
# # Greta-Marie Mueller

# %%
# load pandas
import pandas as pd
import numpy as np
# %matplotlib inline
import matplotlib.pyplot as plt
# load data
litter_control= pd.read_csv("Pittsburgh_Beautify_The_Burgh.csv")
litter_control.head(55)
# Out:
#     FID                                             Group_ Partner  \
# 0     1                               Heinz History Center    None
# 1     2                   Allegheny County Adult Probation    None
# 2     3                         West End Children's Center    None
# 3     4                                PA Resource Council    None
# 4     6                           Spring Hill Civic League    None
# 5     7                           Asian Leadership Program    OPDC
# 6     8                 Alpha Phi Omega Kappa Chapter, CMU    OPDC
# 7     9                                          Delta Chi    OPDC
# 8    10                                     Delta Sigma Pi    OPDC
# 9    11                                  Gamma Sigma Sigma    OPDC
# 10   12            National Society of Collegiate Scholars    OPDC
# 11   13                                 Biology Club, Pitt    OPDC
# 12   14                                     Circle K, Pitt    OPDC
# ...

# %%
#Drop council column

# %%
litter_control.drop('Council', axis = 1, inplace = True)
litter_control.drop('FID', axis = 1, inplace = True)

# %%
litter_control.plot(figsize=(12,12))

# %%
litter_control.head(55)
# Out:
#                                                Group_ Partner  \
# 0                                Heinz History Center    None
# 1                    Allegheny County Adult Probation    None
# 2                          West End Children's Center    None
# 3                                 PA Resource Council    None
# 4                            Spring Hill Civic League    None
# 5                            Asian Leadership Program    OPDC
# 6                  Alpha Phi Omega Kappa Chapter, CMU    OPDC
# 7                                           Delta Chi    OPDC
# 8                                      Delta Sigma Pi    OPDC
# 9                                   Gamma Sigma Sigma    OPDC
# 10            National Society of Collegiate Scholars    OPDC
# 11                                 Biology Club, Pitt    OPDC
# 12                                     Circle K, Pitt    OPDC
# 13                                     Sigma Beta Rho    OPDC
# ...

# %%
#which neighborhood has the most groups?

# %%
litter_control.shape
# Out:
# (54, 6)

# %%
litter_control.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 54 entries, 0 to 53
# Data columns (total 6 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Group_        54 non-null     object
#  1   Partner       54 non-null     object
#  2   Neighborhood  54 non-null     object
#  3   IDNumber      54 non-null     int64
#  4   SHAPE_Length  54 non-null     float64
#  5   SHAPE_Area    54 non-null     float64
# dtypes: float64(2), int64(1), object(3)
# memory usage: 2.7+ KB

# %%
#which neighborhood appears most frequent? 
#This determines which one has the most groups
litter_control['Neighborhood'].value_counts().idxmax()
# Out:
# 'Mount Washington'

# %%
#Mount Washington seems to have the most litter control groups. How about the neighborhood with the least?

# %%
litter_control['Neighborhood'].value_counts().idxmin()
# Out:
# 'Allegheny West'

# %%
litter_control.value_counts('Neighborhood')
# Out:
# Neighborhood
# Mount Washington             9
# Central Oakland              7
# South Oakland                6
# North Oakland                5
# North Point Breeze           3
# West Oakland                 2
# Strip District               2
# Carrick                      2
# Allentown                    2
# Spring Hill-City View        1
# South Side Flats             1
# Sheraden                     1
# Shadyside                    1
# Point Breeze                 1
# Allegheny West               1
# Lower Lawrenceville          1
# Hazelwood                    1
# Greenfield                   1
# Elliott                      1
# East Liberty                 1
# Central Business District    1
# Bluff/Uptown                 1
# Beltzhoover                  1
# Arlington                    1
# Homewood South               1
# dtype: int64

# %%
#so there are several neighborhoods that only have one group... Compare with other datasets to find the (potentially) stinkiest neighborhood

# %%
#query mask
query_mask = litter_control['Neighborhood'] == "Allegheny West"
query_mask.head(55)
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# 15    False
# 16    False
# 17    False
# 18    False
# 19    False
# 20    False
# 21    False
# 22    False
# 23    False
# 24    False
# 25    False
# 26    False
# 27    False
# 28    False
# 29    False
# 30    False
# 31    False
# 32    False
# 33    False
# 34    False
# 35    False
# 36    False
# 37    False
# 38    False
# 39    False
# 40    False
# 41    False
# 42    False
# 43     True
# 44    False
# 45    False
# 46    False
# 47    False
# 48    False
# 49    False
# 50    False
# 51    False
# 52    False
# 53    False
# Name: Neighborhood, dtype: bool

# %%
#query mask
query_mask = litter_control['Neighborhood'] == "Beltzhoover"
query_mask.head(55)
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# 15    False
# 16    False
# 17    False
# 18    False
# 19    False
# 20    False
# 21    False
# 22    False
# 23    False
# 24    False
# 25     True
# 26    False
# 27    False
# 28    False
# 29    False
# 30    False
# 31    False
# 32    False
# 33    False
# 34    False
# 35    False
# 36    False
# 37    False
# 38    False
# 39    False
# 40    False
# 41    False
# 42    False
# 43    False
# 44    False
# 45    False
# 46    False
# 47    False
# 48    False
# 49    False
# 50    False
# 51    False
# 52    False
# 53    False
# Name: Neighborhood, dtype: bool

# %%
#test if accurate
litter_control.iloc[43]
# Out:
# Group_          Pittsburgh King PreK-8
# Partner                         School
# Neighborhood            Allegheny West
# IDNumber                            39
# SHAPE_Length               1725.966581
# SHAPE_Area                19151.980159
# Name: 43, dtype: object

# %%
litter_control.iloc[25]
# Out:
# Group_          St. Paul AME Beltzhoover
# Partner                             None
# Neighborhood                 Beltzhoover
# IDNumber                              26
# SHAPE_Length                 1639.648261
# SHAPE_Area                  95490.078141
# Name: 25, dtype: object

# %%
import pandas as pd
import numpy as np
import json
import geopandas as gpd
# %matplotlib inline
#data = geopandas.read_file("Pittsburgh_Beautify_The_Burgh.geojson") 
data = gpd.read_file("Pittsburgh_Beautify_The_Burgh.geojson") 
print(data)
# Out:
#     FID                                             Group_ Partner  \
# 0     1                               Heinz History Center    None
# 1     2                   Allegheny County Adult Probation    None
# 2     3                         West End Children's Center    None
# 3     4                                PA Resource Council    None
# 4     6                           Spring Hill Civic League    None
# 5     7                           Asian Leadership Program    OPDC
# 6     8                 Alpha Phi Omega Kappa Chapter, CMU    OPDC
# 7     9                                          Delta Chi    OPDC
# 8    10                                     Delta Sigma Pi    OPDC
# 9    11                                  Gamma Sigma Sigma    OPDC
# 10   12            National Society of Collegiate Scholars    OPDC
# 11   13                                 Biology Club, Pitt    OPDC
# 12   14                                     Circle K, Pitt    OPDC
# ...

# %%
data.plot(figsize=(20,20))

# %%
ax = data.plot(figsize=(20, 20), alpha=0.5, edgecolor='k')

# %%
data = data.to_crs(epsg=3857)

# %%
import pandas as pd
import geopandas as gpd
import requests
import json
url = 'https://services1.arcgis.com/YZCmUqbcsUpOKfj7/arcgis/rest/services/BeautifyBurgh/FeatureServer/0'
r = requests.get(url)
r
# Out:
# <Response [200]>

# %%
data.iloc[25]
# Out:
# FID                                                            31
# Group_                                   St. Paul AME Beltzhoover
# Partner                                                      None
# Neighborhood                                          Beltzhoover
# Council                                                         3
# IDNumber                                                       26
# SHAPE_Length                                             0.013034
# SHAPE_Area                                               0.000006
# geometry        (POLYGON ((-79.99718995999996 40.4180049430000...
# Name: 25, dtype: object

# %%
data.iloc[25].plot
